# %%
import os
from dotenv import load_dotenv

load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

UNSTRUCTURED_API_KEY = os.getenv("UNSTRUCTURED_API_KEY")

# %%
file_path = "../input/Gated Attention.pdf"

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader(
    file_path=file_path,
    strategy="hi_res",
    partition_via_api=True,
    coordinates = True
    
    # mode="elements",
    # chunking_strategy="by_title",
    # max_characters=800,
    # combine_text_under_n_chars=200,
    # infer_table_structure=True,
    # include_metadata=True
)


docs = []
for doc in loader.lazy_load():
    docs.append(doc)
# Out:
# INFO: HTTP Request: GET https://api.unstructuredapp.io/general/docs "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"

# %%
docs[0]
# Out:
# Document(metadata={'source': '../input/Gated Attention.pdf', 'coordinates': {'points': [[198.1282501220703, 61.8940544128418], [198.1282501220703, 117.3667221069336], [332.2106628417969, 117.3667221069336], [332.2106628417969, 61.8940544128418]], 'system': 'PixelSpace', 'layout_width': 1654, 'layout_height': 2339}, 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': 'Gated Attention.pdf', 'category': 'Image', 'element_id': '328003dc6c13213f30f0d9a888a10cb5'}, page_content='Qwen')

# %%
print(f"Loaded {len(docs)} documents")
print(f"Sample metadata: {docs[1].metadata if docs else 'No docs'}")
# Out:
# Loaded 208 documents
# Sample metadata: {'source': '../input/Gated Attention.pdf', 'is_extracted': 'true', 'coordinates': {'points': [[1326.0623779296875, 94.84130096435547], [1326.0623779296875, 116.85912322998047], [1454.18310546875, 116.85912322998047], [1454.18310546875, 94.84130096435547]], 'system': 'PixelSpace', 'layout_width': 1654, 'layout_height': 2339}, 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': 'Gated Attention.pdf', 'category': 'Header', 'element_id': 'e0f8aad552bfd390c4496e1d7d2a6d14'}

# %% [markdown]
# ## Import Qdrant Store Module

# %%
import sys
sys.path.append('..')  # Add parent directory to path

from qdrant_vectorstore import QdrantStore, create_store_from_documents

# %%
# Reload the module to get the latest changes
import importlib
import qdrant_vectorstore
importlib.reload(qdrant_vectorstore)
from qdrant_vectorstore import QdrantStore, create_store_from_documents

# %%
# Create store and add documents
store = create_store_from_documents(
    documents=docs,
    collection_name="research_papers_main",
    embedding_model="sentence-transformers/all-MiniLM-L6-v2"
)

# Get collection info
info = store.get_collection_info()
# print(f"Collection Info:")
# print(f"  Points: {info['points_count']}")
# print(f"  Status: {info['status']}")
# Out:
# INFO: Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# Embedding dimension: 384
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333 "HTTP/1.1 200 OK"
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections "HTTP/1.1 200 OK"
# Using existing collection: research_papers_main
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main "HTTP/1.1 200 OK"
# Adding 208 documents to Qdrant...
# INFO: HTTP Request: PUT https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points?wait=true "HTTP/1.1 200 OK"
# INFO: HTTP Request: PUT https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points?wait=true "HTTP/1.1 200 OK"
# INFO: HTTP Request: PUT https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points?wait=true "HTTP/1.1 200 OK"
# Successfully added 208 documents
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main "HTTP/1.1 200 OK"

# %% [markdown]
# ## Load Existing Collection from Qdrant Cloud
#
# This demonstrates how to reconnect to your data later without re-uploading.

# %%
# Load existing collection from cloud
print("Loading existing collection...")
store_existing = QdrantStore.from_existing(
    collection_name="research_papers_main",
    embedding_model="sentence-transformers/all-MiniLM-L6-v2"
)

info = store_existing.get_collection_info()
print(f"✓ Loaded collection from Qdrant Cloud")
print(f"  Points: {info['points_count']}")
# Out:
# INFO: Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Loading existing collection...
# Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# Embedding dimension: 384
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333 "HTTP/1.1 200 OK"
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections "HTTP/1.1 200 OK"
# Using existing collection: research_papers_main
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main "HTTP/1.1 200 OK"
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main "HTTP/1.1 200 OK"
# ✓ Loaded collection from Qdrant Cloud
#   Points: 208

# %%
store_existing

# %%
# First, let's check the collection info and see what metadata is available
info = store_existing.get_collection_info()
print("Collection info:")
print(info)
# Out:
# INFO: HTTP Request: GET https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main "HTTP/1.1 200 OK"
# Collection info:
# {'name': 'research_papers_main', 'vectors_count': 208, 'points_count': 208, 'status': <CollectionStatus.GREEN: 'green'>}

# %%
from langchain_core.documents import Document

# Get all points from the collection
all_points = []
offset = None

while True:
    result = store_existing.client.scroll(
        collection_name=store_existing.collection_name,
        limit=100,
        offset=offset,
        with_payload=True,
        with_vectors=False
    )
    
    points, next_offset = result
    all_points.extend(points)
    
    if next_offset is None:
        break
    offset = next_offset
# Out:
# INFO: HTTP Request: POST https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points/scroll "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points/scroll "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://b9c1abff-fc0c-4fba-8838-f0890f5b091f.us-east4-0.gcp.cloud.qdrant.io:6333/collections/research_papers_main/points/scroll "HTTP/1.1 200 OK"

# %%
# Filter by page_number = 1
page_1_points = [p for p in all_points if p.payload.get('metadata', {}).get('page_number') == 1]

print(f"Total points in collection: {len(all_points)}")
print(f"Points with page_number = 1: {len(page_1_points)}")
print("\n" + "="*80 + "\n")

# Display the data
for i, point in enumerate(page_1_points, 1):
    print(f"Document {i}:")
    print(f"  Content: {point.payload.get('page_content', '')[:150]}...")
    print(f"  Metadata: {point.payload.get('metadata', {})}")
    print("-" * 80)

# %% [markdown]
# ## Extract Different Content Types by Category

# %%
# 1. Extract all IMAGES
print("=" * 80)
print("IMAGES")
print("=" * 80)

images = [p for p in all_points if p.payload.get('metadata', {}).get('category') == 'Image']

print(f"\nTotal Images Found: {len(images)}\n")

for i, point in enumerate(images, 1):
    metadata = point.payload.get('metadata', {})
    print(f"Image {i}:")
    print(f"  Page Number: {metadata.get('page_number', 'N/A')}")
    print(f"  Source: {metadata.get('source', 'N/A')}")
    print(f"  Element ID: {metadata.get('element_id', 'N/A')}")
    print(f"  Content Preview: {point.payload.get('page_content', '')[:100]}")
    print("-" * 80)
# Out:
# ================================================================================
# IMAGES
# ================================================================================
#
# Total Images Found: 10
#
# Image 1:
#   Page Number: 7
#   Source: ../input/Gated Attention.pdf
#   Element ID: 618d8f148aae5341f7338ddd265553ca
#   Content Preview: SDPA_Elementwise HS_Gate Scores Distribution 0.16 T 0.14 = Distribution --- Mean =0.271 0.12 §0.10 g
# --------------------------------------------------------------------------------
# Image 2:
#   Page Number: 14
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6d69c4dd2b617479e949625be152cde6
#   Content Preview: Hidden State Mean - hidden state mean before gate, avg 0.71 hidden state mean after gate, avg 0.05 —
# --------------------------------------------------------------------------------
# Image 3:
#   Page Number: 14
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6441d3e71d5fd63b9b4ac0aad0b33fee
#   Content Preview: Sparsity Ratio of SDPA Output, Threshold le-2 Sparsity Ratio of SDPA Output, Threshold le-3 1.0 -~ s
# --------------------------------------------------------------------------------
# Image 4:
#   Page Number: 1
#   Source: ../input/Gated Attention.pdf
#   Element ID: 328003dc6c13213f30f0d9a888a10cb5
#   Content Preview: Qwen
# --------------------------------------------------------------------------------
# Image 5:
#   Page Number: 7
#   Source: ../input/Gated Attention.pdf
#   Element ID: f68d7a3cea3089f59a6da6a4f7f1726a
#   Content Preview: v_Elementwise_Gate Scores Distribution 016 014 =3 Distribution = Mean = 0.221 202 §0.10 g 0.08 0.06
# --------------------------------------------------------------------------------
# Image 6:
#   Page Number: 7
#   Source: ../input/Gated Attention.pdf
#   Element ID: e2b035046bc2487f17967be05825470f
#   Content Preview: SDPA_Elementwise_Gate Scores Distribution 016 014 =3 Distribution --- Mean =0.116 202 §0.10 g 0.08 2
# --------------------------------------------------------------------------------
# Image 7:
#   Page Number: 16
#   Source: ../input/Gated Attention.pdf
#   Element ID: 810e8f37916c45ab6e47c44bf1cc63ec
#   Content Preview: Massive Activation of baseline first token attention scores of baseline 1.0 1600 | —— first token at
# --------------------------------------------------------------------------------
# Image 8:
#   Page Number: 3
#   Source: ../input/Gated Attention.pdf
#   Element ID: cdc3886fa5359ded424bde372c6b1e5e
#   Content Preview: first token attention scores of baseline baseline, layer 21 baseline, layer 23 10 10 10 —— first tok
# --------------------------------------------------------------------------------
# Image 9:
#   Page Number: 17
#   Source: ../input/Gated Attention.pdf
#   Element ID: b2025f0778b634daadf4dbacff685cab
#   Content Preview: atten_output_gate gate values attention_output_gate_scaler gate values 1.04 1.0 mean std = min 0.8 0
# --------------------------------------------------------------------------------
# Image 10:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: beaaf57fee55d1d32395d8bdac377c44
#   Content Preview: 230 6.05 e 0,045 225 5.95 0.206 W Dense Layer 0.265 baseline avg PPL 5.85 SDPAG 220 Most Effective!
# --------------------------------------------------------------------------------

# %%
# 2. Extract all FORMULAS
print("=" * 80)
print("FORMULAS")
print("=" * 80)

formulas = [p for p in all_points if p.payload.get('metadata', {}).get('category') == 'Formula']

print(f"\nTotal Formulas Found: {len(formulas)}\n")

for i, point in enumerate(formulas, 1):
    metadata = point.payload.get('metadata', {})
    print(f"Formula {i}:")
    print(f"  Page Number: {metadata.get('page_number', 'N/A')}")
    print(f"  Source: {metadata.get('source', 'N/A')}")
    print(f"  Element ID: {metadata.get('element_id', 'N/A')}")
    print(f"  Content: {point.payload.get('page_content', '')}")
    print("-" * 80)
# Out:
# ================================================================================
# FORMULAS
# ================================================================================
#
# Total Formulas Found: 8
#
# Formula 1:
#   Page Number: 3
#   Source: ../input/Gated Attention.pdf
#   Element ID: 3e67a56dd7a7449ddaf432621b27d1db
#   Content: Y ′ = g(Y ,X,Wθ,σ) = Y ⊙ σ(XWθ), (5)
# --------------------------------------------------------------------------------
# Formula 2:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: effc309511043e90b2381f64fc5988e1
#   Content: Q = XWQ, K = XWK, V = XWV . (1)
# --------------------------------------------------------------------------------
# Formula 3:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: db2d8019f1b789433c0d4a475cd7b008
#   Content: k S, 4, (8) = Non-Linearity-Map - W,
# --------------------------------------------------------------------------------
# Formula 4:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: bdcaf43a25616a23266cc5e4a4095f42
#   Content: ) - Non-Linearity-Map (X W Wk,
# --------------------------------------------------------------------------------
# Formula 5:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: 0eed73cab6aac48ecd606f595214ff62
#   Content: ) Attention(Q, K, V') = softmax Vi )v
# --------------------------------------------------------------------------------
# Formula 6:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: 0d4589cc87b2b11394f1c17cbf8d9f60
#   Content: MultiHead(Q,K,V ) = Concat(head1,...,headh), (3)
# --------------------------------------------------------------------------------
# Formula 7:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: e3184a32f50c1b3961d813cdc5b0dbbc
#   Content: ok i = ( Xi j=0 Sk ij · XjWk V )Wk O = Xi j=0 Sk ij · Xj(Wk V Wk O), (6)
# --------------------------------------------------------------------------------
# Formula 8:
#   Page Number: 3
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6b2e664fc7cc3665d9cf33e61b09e5e2
#   Content: O = MultiHead(Q,K,V )Wo. (4)
# --------------------------------------------------------------------------------

# %%
# 3. Extract all TABLES
print("=" * 80)
print("TABLES")
print("=" * 80)

tables = [p for p in all_points if p.payload.get('metadata', {}).get('category') == 'Table']

print(f"\nTotal Tables Found: {len(tables)}\n")

for i, point in enumerate(tables, 1):
    metadata = point.payload.get('metadata', {})
    print(f"Table {i}:")
    print(f"  Page Number: {metadata.get('page_number', 'N/A')}")
    print(f"  Source: {metadata.get('source', 'N/A')}")
    print(f"  Element ID: {metadata.get('element_id', 'N/A')}")
    print(f"  Content Preview: {point.payload.get('page_content', '')[:200]}")
    print("-" * 80)
# Out:
# ================================================================================
# TABLES
# ================================================================================
#
# Total Tables Found: 6
#
# Table 1:
#   Page Number: 4
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6bfc41074f8e70d18e766a54eb9225e5
#   Content Preview: Method Act Func Score Shape Added Param Avg PPL Hellaswag MMLU GSM8k C-eval Reference Baselines (Baseline uses q = 32,k = 4. All methods use dk = 128.) (1) Baseline - - 0 6.026 73.07 58.79 52.92 (2) k
# --------------------------------------------------------------------------------
# Table 2:
#   Page Number: 5
#   Source: ../input/Gated Attention.pdf
#   Element ID: 68ae31338ccba8502506d6cd48de4f15
#   Content Preview: Method Max LR Avg PPL HumanEval MMLU GSM8k Hellaswag C-eval CMMLU 28 Layer, 1.7B Parameters, 400B Tokens, Batch Size=1024 (1) Baseline (2) SDPA Elementwise 4.0 × 10−3 4.0 × 10−3 7.499 7.404 28.66 29.2
# --------------------------------------------------------------------------------
# Table 3:
#   Page Number: 8
#   Source: ../input/Gated Attention.pdf
#   Element ID: f5feb88a18d95ba15f6072063901c220
#   Content Preview: Method Baseline SDPA-Gate 4k 88.89 90.56 8k 16k 85.88 83.15 87.11 84.61 YaRN Extended 32k 79.50 79.77 64k - - Baseline SDPA-Gate 82.90(-6.0) 88.13(-2.4) 71.52(-14.4) 80.01(-7.1) 61.23(-21.9) 76.74(-7.
# --------------------------------------------------------------------------------
# Table 4:
#   Page Number: 7
#   Source: ../input/Gated Attention.pdf
#   Element ID: 41ae0c0a7a58e0f826993855e5057309
#   Content Preview: Method Act-Func Gate Score M-Act F-Attn PPL Hellaswag MMLU GSM8k (1) Baseline - - 1053 0.467 6.026 73.07 58.79 52.92 (2) SDPA Elementwise Gate Sigmoid 0.116 94 0.048 5.761 74.64 60.82 55.27 (3) SDPA H
# --------------------------------------------------------------------------------
# Table 5:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: 2fb4c89f32f8eff2d3080c25acc72fd8
#   Content Preview: Method Activation Function Avg PPL Hellaswag MMLU GSM8k C-eval (1) Baseline - 6.026 73.07 58.79 52.92 60.26 (2) SDPA Elementwise Gate Sigmoid 5.761 74.64 60.82 55.27 62.20 (3) v Elementwise Gate Sigmo
# --------------------------------------------------------------------------------
# Table 6:
#   Page Number: 13
#   Source: ../input/Gated Attention.pdf
#   Element ID: 071e6f7c4ee6d117809985c5a71ead36
#   Content Preview: Method Added Param (M) PPL MMLU GSM8k Hellaswag C-eval (1) Baseline (q32, kv4) - 6.026 58.79 52.92 73.07 60.26 (2) Switch kv, 8top8 38 5.847 59.17 52.54 73.32 61.01 (3) Switch kv, 4top4 13 5.935 58.14
# --------------------------------------------------------------------------------

# %%
# 4. Extract all TITLES
print("=" * 80)
print("TITLES")
print("=" * 80)

titles = [p for p in all_points if p.payload.get('metadata', {}).get('category') == 'Title']

print(f"\nTotal Titles Found: {len(titles)}\n")

for i, point in enumerate(titles, 1):
    metadata = point.payload.get('metadata', {})
    print(f"Title {i}:")
    print(f"  Page Number: {metadata.get('page_number', 'N/A')}")
    print(f"  Source: {metadata.get('source', 'N/A')}")
    print(f"  Element ID: {metadata.get('element_id', 'N/A')}")
    print(f"  Content: {point.payload.get('page_content', '')}")
    print("-" * 80)
# Out:
# ================================================================================
# TITLES
# ================================================================================
#
# Total Titles Found: 27
#
# Title 1:
#   Page Number: 14
#   Source: ../input/Gated Attention.pdf
#   Element ID: 182038af5456c3ccedcb19a3f4aa2e11
#   Content: A.4 More Layerwise Gating Scores
# --------------------------------------------------------------------------------
# Title 2:
#   Page Number: 4
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6d05d6aa4cf8fbf18cde0243865622e6
#   Content: 3.2 Main Results
# --------------------------------------------------------------------------------
# Title 3:
#   Page Number: 13
#   Source: ../input/Gated Attention.pdf
#   Element ID: e11933b84ed4bd634be26842db72ec86
#   Content: A.1 Switch Head Baselines
# --------------------------------------------------------------------------------
# Title 4:
#   Page Number: 13
#   Source: ../input/Gated Attention.pdf
#   Element ID: c54149cbb1d67644283ad7dbb49cbcaa
#   Content: A.2 More Discussion on Sparse Gating Score
# --------------------------------------------------------------------------------
# Title 5:
#   Page Number: 1
#   Source: ../input/Gated Attention.pdf
#   Element ID: 319ddf828c95298415d9f0e04839bfbc
#   Content: 1 Introduction
# --------------------------------------------------------------------------------
# Title 6:
#   Page Number: 9
#   Source: ../input/Gated Attention.pdf
#   Element ID: 0fc828de806e04c98f22c4aca9fb70f6
#   Content: 6 Conclusion
# --------------------------------------------------------------------------------
# Title 7:
#   Page Number: 4
#   Source: ../input/Gated Attention.pdf
#   Element ID: 5d62feafb59d4cf300baf18e75b6e5d1
#   Content: 3 Experiments
# --------------------------------------------------------------------------------
# Title 8:
#   Page Number: 13
#   Source: ../input/Gated Attention.pdf
#   Element ID: d973a84bca1c6c945069af9712f3c5bf
#   Content: A Supplement Experiments
# --------------------------------------------------------------------------------
# Title 9:
#   Page Number: 4
#   Source: ../input/Gated Attention.pdf
#   Element ID: 8e66b0a6f93a25eb7ca15ecb9e5bc863
#   Content: 3.1 Experimental Setups
# --------------------------------------------------------------------------------
# Title 10:
#   Page Number: 14
#   Source: ../input/Gated Attention.pdf
#   Element ID: 79625b73d75ccd6cae223f7e7e31c96f
#   Content: A.3 Layerwise Massive Activations and Attention Sinks
# --------------------------------------------------------------------------------
# Title 11:
#   Page Number: 10
#   Source: ../input/Gated Attention.pdf
#   Element ID: 20e3949137ce57ec344f926f5e01e0fb
#   Content: References
# --------------------------------------------------------------------------------
# Title 12:
#   Page Number: 9
#   Source: ../input/Gated Attention.pdf
#   Element ID: 1395a5fcab8187b0368b9d8d8bb966bc
#   Content: 5 Related Works
# --------------------------------------------------------------------------------
# Title 13:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: 80dacad8f4b4285f756f52b6fed0507a
#   Content: 2 Gated-Attention Layer
# --------------------------------------------------------------------------------
# Title 14:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: c4e49336e6cc28003ccca156b592f019
#   Content: 4.1 Non-linearity Improves the Expressiveness of Low-Rank Mapping in Attention
# --------------------------------------------------------------------------------
# Title 15:
#   Page Number: 9
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6d935c221a25caca7c88b82f02100c88
#   Content: 5.1 Gating in Neural Networks
# --------------------------------------------------------------------------------
# Title 16:
#   Page Number: 8
#   Source: ../input/Gated Attention.pdf
#   Element ID: 9c6cd2213c131a8ba51b4be7c3a26657
#   Content: 4.3 SDPA Output Gating Reduces Attention-Sink
# --------------------------------------------------------------------------------
# Title 17:
#   Page Number: 7
#   Source: ../input/Gated Attention.pdf
#   Element ID: 754cdeeb3af444aee02858e1fdae1e78
#   Content: 4.2 Gating Introduces Input-Dependent Sparsity
# --------------------------------------------------------------------------------
# Title 18:
#   Page Number: 9
#   Source: ../input/Gated Attention.pdf
#   Element ID: 02fd8a99419bfff8de6164f774fee48e
#   Content: 5.2 Attention Sink
# --------------------------------------------------------------------------------
# Title 19:
#   Page Number: 10
#   Source: ../input/Gated Attention.pdf
#   Element ID: 335bdbea4488e3f24c632f3e87d0f6ef
#   Content: Limitations
# --------------------------------------------------------------------------------
# Title 20:
#   Page Number: 4
#   Source: ../input/Gated Attention.pdf
#   Element ID: 6e734cfbb65ef6da87fef4c0360aad36
#   Content: 3.2.1 Gated Attention for MoE models
# --------------------------------------------------------------------------------
# Title 21:
#   Page Number: 5
#   Source: ../input/Gated Attention.pdf
#   Element ID: 16e05447b89692e8c234d0f00b9b7e48
#   Content: 3.2.2 Gated Attention for Dense Models.
# --------------------------------------------------------------------------------
# Title 22:
#   Page Number: 3
#   Source: ../input/Gated Attention.pdf
#   Element ID: d8324398c237a7729014cef79163cba9
#   Content: 2.2 Augmenting Attention Layer with Gating Mechanisms
# --------------------------------------------------------------------------------
# Title 23:
#   Page Number: 15
#   Source: ../input/Gated Attention.pdf
#   Element ID: 10d66537bfb8149bfc37f65d1a96a1b4
#   Content: A.5 Other Attempt to Stabilize Training
# --------------------------------------------------------------------------------
# Title 24:
#   Page Number: 6
#   Source: ../input/Gated Attention.pdf
#   Element ID: fccfc109a58bdea77ce0cf258fd948e8
#   Content: 4 Analysis: Non-Linearity, Sparsity, and Attention-Sink-Free
# --------------------------------------------------------------------------------
# Title 25:
#   Page Number: 2
#   Source: ../input/Gated Attention.pdf
#   Element ID: af313321c7784a080e127f9706f2f4f9
#   Content: 2.1 Preliminary: Multi-Head Softmax Attention
# --------------------------------------------------------------------------------
# Title 26:
#   Page Number: 1
#   Source: ../input/Gated Attention.pdf
#   Element ID: f77e80976b6214b47fbddfea94aa90d7
#   Content: Abstract
# --------------------------------------------------------------------------------
# Title 27:
#   Page Number: 8
#   Source: ../input/Gated Attention.pdf
#   Element ID: 19af6ee4a16edd161c5e0dc70c9b2a87
#   Content: 4.4 SDPA Output Gating Facilitates Context Length Extension
# --------------------------------------------------------------------------------

# %%
# 5. Summary of all categories
print("=" * 80)
print("SUMMARY: ALL CATEGORIES")
print("=" * 80)

# Get all unique categories
categories = {}
for point in all_points:
    category = point.payload.get('metadata', {}).get('category', 'Unknown')
    categories[category] = categories.get(category, 0) + 1

print(f"\nTotal Documents: {len(all_points)}\n")
print("Category Distribution:")
for cat, count in sorted(categories.items(), key=lambda x: x[1], reverse=True):
    print(f"  {cat}: {count}")
print("=" * 80)
# Out:
# ================================================================================
# SUMMARY: ALL CATEGORIES
# ================================================================================
#
# Total Documents: 208
#
# Category Distribution:
#   NarrativeText: 63
#   ListItem: 58
#   Title: 27
#   Footer: 19
#   FigureCaption: 12
#   Image: 10
#   Formula: 8
#   Table: 6
#   UncategorizedText: 3
#   Header: 2
# ================================================================================

# %%
# 6. Filter by BOTH category and page number
# Example: Get all titles from page 1

target_category = "Title"  # Change to: "Image", "Formula", "Table", "CompositeElement", etc.
target_page = 1  # Change to desired page number

filtered_results = [
    p for p in all_points 
    if p.payload.get('metadata', {}).get('category') == target_category 
    
]

print("=" * 80)
print(f"FILTERED RESULTS: {target_category} from Page {target_page}")
print("=" * 80)
print(f"\nFound {len(filtered_results)} items\n")

for i, point in enumerate(filtered_results, 1):
    metadata = point.payload.get('metadata', {})
    print(f"{target_category} {i}:")
    print(f"  Page Number: {metadata.get('page_number', 'N/A')}")
    print(f"  Element ID: {metadata.get('element_id', 'N/A')}")
    print(f"  Content: {point.payload.get('page_content', '')}")
    print("-" * 80)
# Out:
# ================================================================================
# FILTERED RESULTS: Title from Page 1
# ================================================================================
#
# Found 27 items
#
# Title 1:
#   Page Number: 14
#   Element ID: 182038af5456c3ccedcb19a3f4aa2e11
#   Content: A.4 More Layerwise Gating Scores
# --------------------------------------------------------------------------------
# Title 2:
#   Page Number: 4
#   Element ID: 6d05d6aa4cf8fbf18cde0243865622e6
#   Content: 3.2 Main Results
# --------------------------------------------------------------------------------
# Title 3:
#   Page Number: 13
#   Element ID: e11933b84ed4bd634be26842db72ec86
#   Content: A.1 Switch Head Baselines
# --------------------------------------------------------------------------------
# Title 4:
#   Page Number: 13
#   Element ID: c54149cbb1d67644283ad7dbb49cbcaa
#   Content: A.2 More Discussion on Sparse Gating Score
# --------------------------------------------------------------------------------
# Title 5:
#   Page Number: 1
#   Element ID: 319ddf828c95298415d9f0e04839bfbc
#   Content: 1 Introduction
# --------------------------------------------------------------------------------
# Title 6:
#   Page Number: 9
#   Element ID: 0fc828de806e04c98f22c4aca9fb70f6
#   Content: 6 Conclusion
# --------------------------------------------------------------------------------
# Title 7:
#   Page Number: 4
#   Element ID: 5d62feafb59d4cf300baf18e75b6e5d1
#   Content: 3 Experiments
# --------------------------------------------------------------------------------
# Title 8:
#   Page Number: 13
#   Element ID: d973a84bca1c6c945069af9712f3c5bf
#   Content: A Supplement Experiments
# --------------------------------------------------------------------------------
# Title 9:
#   Page Number: 4
#   Element ID: 8e66b0a6f93a25eb7ca15ecb9e5bc863
#   Content: 3.1 Experimental Setups
# --------------------------------------------------------------------------------
# Title 10:
#   Page Number: 14
#   Element ID: 79625b73d75ccd6cae223f7e7e31c96f
#   Content: A.3 Layerwise Massive Activations and Attention Sinks
# --------------------------------------------------------------------------------
# Title 11:
#   Page Number: 10
#   Element ID: 20e3949137ce57ec344f926f5e01e0fb
#   Content: References
# --------------------------------------------------------------------------------
# Title 12:
#   Page Number: 9
#   Element ID: 1395a5fcab8187b0368b9d8d8bb966bc
#   Content: 5 Related Works
# --------------------------------------------------------------------------------
# Title 13:
#   Page Number: 2
#   Element ID: 80dacad8f4b4285f756f52b6fed0507a
#   Content: 2 Gated-Attention Layer
# --------------------------------------------------------------------------------
# Title 14:
#   Page Number: 6
#   Element ID: c4e49336e6cc28003ccca156b592f019
#   Content: 4.1 Non-linearity Improves the Expressiveness of Low-Rank Mapping in Attention
# --------------------------------------------------------------------------------
# Title 15:
#   Page Number: 9
#   Element ID: 6d935c221a25caca7c88b82f02100c88
#   Content: 5.1 Gating in Neural Networks
# --------------------------------------------------------------------------------
# Title 16:
#   Page Number: 8
#   Element ID: 9c6cd2213c131a8ba51b4be7c3a26657
#   Content: 4.3 SDPA Output Gating Reduces Attention-Sink
# --------------------------------------------------------------------------------
# Title 17:
#   Page Number: 7
#   Element ID: 754cdeeb3af444aee02858e1fdae1e78
#   Content: 4.2 Gating Introduces Input-Dependent Sparsity
# --------------------------------------------------------------------------------
# Title 18:
#   Page Number: 9
#   Element ID: 02fd8a99419bfff8de6164f774fee48e
#   Content: 5.2 Attention Sink
# --------------------------------------------------------------------------------
# Title 19:
#   Page Number: 10
#   Element ID: 335bdbea4488e3f24c632f3e87d0f6ef
#   Content: Limitations
# --------------------------------------------------------------------------------
# Title 20:
#   Page Number: 4
#   Element ID: 6e734cfbb65ef6da87fef4c0360aad36
#   Content: 3.2.1 Gated Attention for MoE models
# --------------------------------------------------------------------------------
# Title 21:
#   Page Number: 5
#   Element ID: 16e05447b89692e8c234d0f00b9b7e48
#   Content: 3.2.2 Gated Attention for Dense Models.
# --------------------------------------------------------------------------------
# Title 22:
#   Page Number: 3
#   Element ID: d8324398c237a7729014cef79163cba9
#   Content: 2.2 Augmenting Attention Layer with Gating Mechanisms
# --------------------------------------------------------------------------------
# Title 23:
#   Page Number: 15
#   Element ID: 10d66537bfb8149bfc37f65d1a96a1b4
#   Content: A.5 Other Attempt to Stabilize Training
# --------------------------------------------------------------------------------
# Title 24:
#   Page Number: 6
#   Element ID: fccfc109a58bdea77ce0cf258fd948e8
#   Content: 4 Analysis: Non-Linearity, Sparsity, and Attention-Sink-Free
# --------------------------------------------------------------------------------
# Title 25:
#   Page Number: 2
#   Element ID: af313321c7784a080e127f9706f2f4f9
#   Content: 2.1 Preliminary: Multi-Head Softmax Attention
# --------------------------------------------------------------------------------
# Title 26:
#   Page Number: 1
#   Element ID: f77e80976b6214b47fbddfea94aa90d7
#   Content: Abstract
# --------------------------------------------------------------------------------
# Title 27:
#   Page Number: 8
#   Element ID: 19af6ee4a16edd161c5e0dc70c9b2a87
#   Content: 4.4 SDPA Output Gating Facilitates Context Length Extension
# --------------------------------------------------------------------------------
